# %%
import json
import re
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
import string

input_file_indeed = '.\\indeed_listings.json'
input_file_techno_jobs = '.\\technojobs_listings.json'
input_file_reed = '.\\Reed_listings.json'
input_file_24 = '.\\jobs24_listings.json'
input_file_jobs_today = '.\\jobs_today_listings.json'



output_file = '.\\all_jobs.json'

# %%
##LOADING AND CONCATING THE DATA
with open(input_file_indeed) as f:
    data_indeed = json.load(f)

with open(input_file_techno_jobs) as f:
    data_techno = json.load(f)
    
with open(input_file_reed) as f:
    data_reed = json.load(f)

with open(input_file_24) as f:
    data_24 = json.load(f)
    
with open(input_file_jobs_today) as f:
    data_today = json.load(f)

# %%
def lowercase_strip_reed_techno(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(' ','').split(',')[-1]
        return sentence
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''
    
def lowercase_strip_indeed(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(' ','').split('-')[-1]
        return sentence
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''

def lowercase_strip_24(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(' ','').split(',')[0]
        return sentence
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''
    
def lowercase_strip_today1(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('Posted', '').replace('Salary', '').replace('\r', '').replace('\t', '').replace('\n', '').replace('Recruiter','').strip().split(',')
        return sentence[0]
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''
    
def lowercase_strip_today2(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
#         sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(' ','').split(',')[0]
        return sentence[4]
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''
    
def lowercase_strip_indeed2(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        wanted_list = ['day', 'month', 'year','months', 'days']
        sentence = [word for word in sentence if 'day' in word or 'month' in word ]
        if len(sentence) > 0:
            result = sentence[0].replace('-','').strip()
        else:
            result = 'Not available'
        return result
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''
    
def lowercase_strip_technojob(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\t', '').replace('\n', '').replace('Recruiter','').strip().split(',')
        return sentence[0]
    elif isinstance(sentence, (str,)):
        result = sentence.replace('\n','').strip().lower()
        return result
    else:
        return ''
    
    
def lowercase_strip_reed(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(',','.').replace('..','.').strip()
        return sentence
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''    
    
  
    
def lowercase_strip_reed2(sentence):
    '''
    strip all the non-alphabetical characters
    '''
    if isinstance(sentence, (list,)):
        sentence = ' '.join(sentence).replace('\r', '').replace('\n', '').replace(',','.').replace('..','.').strip().split(' ')[1]
        return sentence
    elif isinstance(sentence, (str,)):
        clean_text = sentence.strip().lower()
        result = re.sub(r"[^a-zA-Z]+", ' ', clean_text)
        return result
    else:
        return ''

# %%
STOPWORD = stopwords.words('english') + list(string.punctuation)

# %%
def clean_discription(descrip_list):
    if isinstance(descrip_list, (list,)):
        descrip_list = ' '.join(descrip_list).replace('\r', '').replace('\n', '').replace('\t','').strip()
#         clean_descrip =' '.join([i for i in word_tokenize(descrip_list.lower()) if i not in STOPWORD])
    return descrip_list

# %%
for i in data_today:
    location_clean = lowercase_strip_today2(i['location'])
    d1 = {'location': location_clean}
    company_clean = lowercase_strip_today1(i['company'])
    d2 = {'company': company_clean}
    title_clean = lowercase_strip_today2(i['title'])
    d3 = {'title': title_clean}
    descrip_clean = clean_discription(i['description'])
    d4 = {'description': descrip_clean}
    salary_clean = lowercase_strip_today1(i['salary'])
    d5 = {'salary': salary_clean}
    posted_clean = lowercase_strip_today1(i['date_listed'])
    d6 = {'date_listed': posted_clean}

    
    i.update(d1)
    i.update(d2)
    i.update(d3)
    i.update(d4)
    i.update(d5)
    i.update(d6)

# %%
for i in data_24:
    location_clean = lowercase_strip_24(i['location'])
    d1 = {'location': location_clean}
    company_clean = lowercase_strip_24(i['company'])
    d2 = {'company': company_clean}
    title_clean = lowercase_strip_24(i['title'])
    d3 = {'title': title_clean}
    descrip_clean = clean_discription(i['description'])
    d4 = {'description': descrip_clean}
    salary_clean = lowercase_strip_24(i['salary'])
    i.update(d1)
    i.update(d2)
    i.update(d3)
    i.update(d4)

# %%
for i in data_indeed:
    location_clean = lowercase_strip_indeed(i['location'])
    d1 = {'location': location_clean}
    company_clean = lowercase_strip_indeed(i['company'])
    d2 = {'company': company_clean}
    title_clean = lowercase_strip_indeed(i['title'])
    d3 = {'title': title_clean}
    descrip_clean = clean_discription(i['description'])
    d4 = {'description': descrip_clean}
    posted_clean = lowercase_strip_indeed2(i['date_listed'])
    d6 = {'date_listed': posted_clean}

    i.update(d1)
    i.update(d2)
    i.update(d3)
    i.update(d4)
    i.update(d6)

# %%
for i in data_techno:
    location_clean = lowercase_strip_reed_techno(i['location'])
    d1 = {'location': location_clean}
    company_clean = lowercase_strip_reed_techno(i['company'])
    d2 = {'company': company_clean}
    title_clean = lowercase_strip_reed_techno(i['title'])
    d3 = {'title': title_clean}
    descrip_clean = clean_discription(i['description'])
    d4 = {'description': descrip_clean}
    salary_clean = lowercase_strip_technojob(i['salary'])
    d5 = {'salary': salary_clean}
    posted_clean = lowercase_strip_technojob(i['date_listed'])
    d6 = {'date_listed': posted_clean}

    
    i.update(d1)
    i.update(d2)
    i.update(d3)
    i.update(d4)
    i.update(d5)
    i.update(d6)

# %%
for i in data_reed:
    location_clean = lowercase_strip_reed_techno(i['location'])
    d1 = {'location': location_clean}
    company_clean = lowercase_strip_reed_techno(i['company'])
    d2 = {'company': company_clean}
    title_clean = lowercase_strip_reed_techno(i['title'])
    d3 = {'title': title_clean}
    descrip_clean = clean_discription(i['description'])
    d4 = {'description': descrip_clean}
    salary_clean = lowercase_strip_reed(i['salary'])
    d5 = {'salary': salary_clean}
    posted_clean = lowercase_strip_reed2(i['date_listed'])
    d6 = {'date_listed': posted_clean}

    
    i.update(d1)
    i.update(d2)
    i.update(d3)
    i.update(d4)
    i.update(
# 3965  Assistant Management Accountant £25,000 - £30,...
# 3966  Job Title:  Service Engineer    Location:  Bas...
# 3967  Genomics/Project Management/PM/Clinical Scient...
# 3968  General Manager   ??23, - ??3, per annum (OTE ...
# 3969  Genomics/Project Management/PM/Clinical Scient...
# 3970  Paid Media Team Lead / Senior PPC     Brighton...
# 3971  We have a fantastic opportunity for you if you...
# 3972  Job Description   Advanced are one of the UK's...
# 3973  Home Carer - ??8.75 per hour - Guaranteed Hour...
#
#                                 location  \
# 3874                          Birmingham
# 3875                              London
# 3876                       East Midlands
# 3877                     England, London
# 3878                          Manchester
# 3879                              London
# 3880                  North West England
# 3881                     England, London
# 3882                          Manchester
# 3883            England, Gloucestershire
# 3884                          Manchester
# 3885                  North West England
# 3886                  North West England
# 3887                    Ipswich, Suffolk
# 3888        England, Oxfordshire, Oxford
# 3889                         East London
# 3890                      City of London
# 3891                          Manchester
# 3892           Leicester, Leicestershire
# 3893                              London
# 3894                              London
# 3895                              London
# 3896                  South East England
# 3897                    London (Greater)
# 3898      Manchester, Greater Manchester
# 3899                      Wales, Cardiff
# 3900                    London (Greater)
# 3901     London (East), London (Greater)
# 3902  England, Hertfordshire, St. Albans
# 3903                  North West England
# ...                                  ...
# 3944                            Chiswick
# 3945                         South Wales
# 3946                              London
# 3947                West Midlands Region
# 3948                Bournemouth, England
# 3949                     London, England
# 3950                      Cambridgeshire
# 3951  London (Central), London (Greater)
# 3952                       Home Counties
# 3953                   Fakenham, England
# 3954                          Manchester
# 3955            Bury, Greater Manchester
# 3956                       Hertfordshire
# 3957                              London
# 3958                     Millom, England
# 3959  London (Central), London (Greater)
# 3960         South West England, England
# 3961                              London
# 3962                          Birmingham
# 3963                          Manchester
# 3964                     London, England
# 3965                    England, Bristol
# 3966                      Wellingborough
# 3967                           Cambridge
# 3968                   North Lanarkshire
# 3969                           Cambridge
# 3970                            Brighton
# 3971                   North Lanarkshire
# 3972                               Leeds
# 3973                   North Lanarkshire
#
#                                                  salary  \
# 3874                    £28000.00 - £42000.00 per annum
# 3875                                         Negotiable
# 3876  £25000 - £30000 per annum + SALARY IS AN AGENC...
# 3877                £3000 - £25000 per annum + benefits
# 3878                    £40000.00 - £60000.00 per annum
# 3879                            dependent on experience
# 3880                                           c£20-£30
# 3881     £60000 - £70000 per annum + Excellent Benefits
# 3882                    £35000.00 - £45000.00 per annum
# 3883                                         Negotiable
# 3884                    £25000.00 - £35000.00 per annum
# 3885                                           c£20-£26
# 3886                                           c£20-£30
# 3887                                                £31
# 3888                          £40000 - £45000 per annum
# 3889                          £28000 - £32000 per annum
# 3890                          £22000 - £25000 per annum
# 3891                    £16000.00 - £18000.00 per annum
# 3892                         £Dependent Upon Experience
# 3893                          £45000 - £50000 per annum
# 3894                            dependent on experience
# 3895                             Up to £26000 per annum
# 3896                                           c£20-£26
# 3897               £30K upwards depending on experience
# 3898                                       £Competitive
# 3899                          £38000 - £45000 per annum
# 3900                         £Dependent Upon Experience
# 3901                                 £Competitive + DOE
# 3902                                  £9 - £11 per hour
# 3903                                               c£25
# ...                                                 ...
# 3944        £80000 - £90000 per annum + Company Package
# 3945                   Up to £70000 per annum + + Bonus
# 3946  Base : £85k Benefits: Generous Senior Executiv...
# 3947                                        Competitive
# 3948                                         Negotiable
# 3949                                         Negotiable
# 3950                       Commensurate with experience
# 3951                                          £95k base
# 3952                                         £150k base
# 3953                    £28000.00 - £32000.00 per annum
# 3954  £40000.00 - £55000.00 per annum + OTE 120k + B...
# 3955                                          Up to £50
# 3956                       £35000.00 - £40000 per annum
# 3957        £50000 - £80000 per annum + Company Package
# 3958                    £40000.00 - £45000.00 per annum
# 3959  Base : £110k Benefits:Full executive package B...
# 3960                    £28000.00 - £32000.00 per annum
# 3961                                Up to £9.5 per hour
# 3962  £25000 - £40000 per annum + salary is agency g...
# 3963  £45000.00 - £60000.00 per annum + Company Car ...
# 3964                          £500.00 - £650.00 per day
# 3965                  £25000 - £30000 per annum + study
# 3966                     25000.00 - 45000.00 GBP Annual
# 3967                                   550.00 GBP Daily
# 3968                                        Competitive
# 3969                                   900.00 GBP Daily
# 3970          Competitive  + Excellent Benefits & Perks
# 3971                     22000.00 - 30000.00 GBP Annual
# 3972                                        Competitive
# 3973
#
#                                               title
# 3874                            partnership manager
# 3875       gerber pattern cutter lingerie mat cover
# 3876                 graphic designer childrenswear
# 3877                             accounts assistant
# 3878                                 design manager
# 3879             social media content editor luxury
# 3880       ladies nightwear and loungewear designer
# 3881   transaction advisory services senior manager
# 3882            senior ladieswear knitwear designer
# 3883                        interim head of finance
# 3884                                 denim designer
# 3885    assistant merchandiser footwear accessories
# 3886              men s designer jackets and sweats
# 3887                     senior accountant top firm
# 3888                               finance analyst
# 3889              international wholesale executive
# 3890     pr executive luxury british heritage brand
# 3891                 assistant garment technologist
# 3892                       fashion graphic designer
# 3893   brand manager young trend fashion womenswear
# 3894                       studio assistant fashion
# 3895      crm and social media exec luxury homeware
# 3896            ladies lingerie activewear designer
# 3897  creative cad pattern cutter product developer
# 3898                                senior designer
# 3899          practice accountant partner designate
# 3900                                  crm executive
# 3901           womenswear sales and account manager
# 3902                                purchase ledger
# 3903          designer wallcoverings and home d cor
# ...                                             ...
# 3944                 sales director southern europe
# 3945                            operations director
# 3946                      director of finance fd x
# 3947                             operations manager
# 3948                                payroll manager
# 3949                           hr payroll assistant
# 3950                   business development manager
# 3951                    senior project manager spm
# 3952            divisional finance director dfd ft
# 3953                                     hr advisor
# 3954            senior business development manager
# 3955                     hr and od business manager
# 3956                              packaging manager
# 3957                                  head of sales
# 3958                         hr and payroll manager
# 3959             head of design international hodi
# 3960                      regional events recruiter
# 3961            part time skincare sales consultant
# 3962                 sales account manager menswear
# 3963      regional sales manager formwork falsework
# 3964          interim hr process harmonisation lead
# 3965                assistant management accountant
# 3966                               service engineer
# 3967                       genomics project manager
# 3968                        general manager glasgow
# 3969                     programme manager genomics
# 3970                paid media team lead senior ppc
# 3971                   senior permanents consultant
# 3972                      junior support consultant
# 3973                    home carer east kilbride ph
#
# [100 rows x 7 columns]

# %%
df_24['salary'] = df_24['salary'].replace('£','-')
df_24['company'] = df_24['company'].replace('','-')

# %%
df_reed['date_listed'] = df_reed['date_listed'].replace('Today', '13-03-2019')

# %%
import datetime
df_today['date_listed'] = df_today['date_listed'].apply(lambda x: datetime.datetime.strptime(x, "%d %b %Y").strftime("%d-%m-%Y"))

# %%
df_techno['date_listed'] = df_techno['date_listed'].replace(regex= r'^today*', value='13th march').str.split(',').str[0]
df_techno['date_listed'] = df_techno['date_listed'].replace('yesterday','12th march')
df_techno['date_listed'] = df_techno['date_listed'].str.replace('th','').str.replace('rd','').str.replace('nd','').str.replace('st','')
df_techno['date_listed'] = df_techno['date_listed'].apply(lambda x: datetime.datetime.strptime(x, "%d %B").strftime("%d-%m-2019"))
# df_techno['date_listed'].value_counts()

# %%
df_indeed['date_listed'] = '21-03-2019'

# %%
all_dfs = [df_reed,df_24,df_today, df_indeed ,df_techno]

# %%
df = pd.concat(all_dfs).reset_index(drop=True)

# %%
df['location'] = df['location'].str.lower()

# %%
lat_long = pd.read_csv("Uk_cities_long_lat.csv")

df = df.merge(lat_long,how ='left', right_on = 'City',left_on = 'location')

# %%
len(df[df['lat'].isnull()])  #15439 with no coordinates
# df[df['lat'].isnull()]['']
df.loc[df['lat'].isnull(),['lat']] = 51.509865
df.loc[df['lat'].isnull(),['long'] ]= -0.118092

# %%
df.drop(columns='City',inplace= True)

# %%
df.to_json('all_jobs.json', orient = 'records')

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://www.reed.co.uk/jobs/clinical-developme...
# 1  https://www.reed.co.uk/jobs/mixed-tax-senior-t...
# 2  https://www.reed.co.uk/jobs/marketing-executiv...
# 3  https://www.reed.co.uk/jobs/new-product-develo...
# 4  https://www.reed.co.uk/jobs/technical-accounta...
#
#                                  company date_listed  \
# 0              nhs greater glasgow clyde  13-03-2019
# 1            mcginnis loy associates ltd  13-03-2019
# 2                reed marketing creative  13-03-2019
# 3               consult search selection  13-03-2019
# 4  insight recruitment solutions limited  13-03-2019
#
#                                          description        location  \
# 0  Apply on employer's website                   ...     lanarkshire
# 1  Apply now                                     ...          london
# 2  Apply now                                     ...          london
# 3  Apply now                                     ...  southyorkshire
# 4  Apply now                                     ...          london
#
#                         salary  \
# 0  £32.157 - £42.544 per annum
# 1  £35.000 - £45.000 per annum
# 2     £13.50 - £18.00 per hour
# 3  £25.000 - £30.000 per annum
# 4  £55.000 - £60.000 per annum
#
#                                                title        lat      long
# 0             clinical development fellow in urology  51.509865       NaN
# 1  mixed tax senior tax accountant top accounting...  51.509865 -0.118092
# 2  marketing executive leading celebrity restaura...  51.509865 -0.118092
# 3                   new product development engineer  51.509865       NaN
# 4                               technical accountant  51.509865 -0.118092

# %%
# df_list = df.values.tolist()

# %%
# with open(output_file, 'w') as f:
#     json.dump(df_list, f)
